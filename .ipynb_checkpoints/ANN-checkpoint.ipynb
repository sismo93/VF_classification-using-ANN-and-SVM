# %%
import pandas as pd
from utils import downloadData,extract_file,to_dataframe,supprimer_lignes_na
from ml_tool import assess_NA,smooth,feature_importance
from ml_algorithms import SVM_Grid_search,SVM_Cross_val,ANN_grid_search
# Out:
# 2023-05-12 20:21:11.957614: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-12 20:21:12.938582: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64::/opt/conda/lib
# 2023-05-12 20:21:12.938705: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64::/opt/conda/lib
# 2023-05-12 20:21:12.938713: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# # Data Statitic

# %%
df = pd.read_excel("final.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95228 entries, 0 to 95227
# Data columns (total 28 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.2  95228 non-null  int64
#  1   Unnamed: 0.1  95228 non-null  int64
#  2   Unnamed: 0    95228 non-null  int64
#  3   label         95228 non-null  object
#  4   signal        95228 non-null  object
#  5   channel       95228 non-null  object
#  6   db            95228 non-null  object
#  7   fs            95228 non-null  int64
#  8   RDAmpM        95228 non-null  float64
#  9   RDAmpSD       95228 non-null  float64
#  10  QRsa          95228 non-null  float64
#  11  QRaSD         95228 non-null  float64
#  12  S             95228 non-null  object
#  13  Q             95228 non-null  object
#  14  R             95228 non-null  object
#  15  mean_rr       95228 non-null  float64
#  16  sdsd          95228 non-null  float64
#  17  pnn50         95228 non-null  float64
#  18  rmssd         95228 non-null  float64
#  19  sdnn          95228 non-null  float64
#  20  lf_power      95228 non-null  int64
#  21  hf_power      95228 non-null  float64
#  22  pos_area      95228 non-null  float64
#  23  neg_area      95228 non-null  float64
#  24  vlf_power     95228 non-null  int64
#  25  ulf_power     95228 non-null  int64
#  26  lfnu          95228 non-null  int64
#  27  hfnu          95228 non-null  float64
# dtypes: float64(13), int64(8), object(7)
# memory usage: 20.3+ MB

# %%
print(df[df["label"] == "NotVF"].count())

# %%
print(df[df["label"] == "VF"].count())

# %% [markdown]
# ## ANN

# %%
import pandas as pd
import numpy as np
import keras
from sklearn.model_selection import GridSearchCV, KFold, train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, accuracy_score
from keras.layers import Dropout
import matplotlib.pyplot as plt
    
import numpy as np
import torch
from torch.nn.modules.module import Module
from torch.optim.lr_scheduler import ReduceLROnPlateau


from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score ,roc_curve
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score, cohen_kappa_score, roc_auc_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def neural_network(X, y, learning_rate=0.001, activation_function='relu', init='normal', neuron1=4, neuron2=2, epochs=1000, batch_size=20, output_path="", early_stop_patience=10,name="you"):

    # Get the number of features (input dimension) from X
    input_dim = X.shape[1]

    # Instantiate the encoder
    le = LabelEncoder()

    # Fit and transform the target variable y
    y = le.fit_transform(y)

    # Function to create model, required for KerasClassifier
    class ANN(nn.Module):
        def __init__(self):
            super(ANN, self).__init__()

            activation_functions = {
                'relu': nn.ReLU(),
                'tanh': nn.Tanh(),
                'sigmoid': nn.Sigmoid(),
                'softmax': nn.Softmax(dim=1)
            }

            init_methods = {
                'normal': nn.init.normal_,
                'uniform': nn.init.uniform_,
                'xavier': nn.init.xavier_uniform_
            }

            self.activation_function = activation_functions[activation_function]

            self.fc1 = nn.Linear(input_dim, neuron1)
            init_methods[init](self.fc1.weight)

            self.fc2 = nn.Linear(neuron1, neuron2)
            init_methods[init](self.fc2.weight)

            self.fc3 = nn.Linear(neuron2, 1)
            init_methods[init](self.fc3.weight)

            self.bn1 = nn.BatchNorm1d(neuron1)
            self.bn2 = nn.BatchNorm1d(neuron2)

        def forward(self, x):
            x = self.activation_function(self.fc1(x))
            x = self.bn1(x)
            x = self.activation_function(self.fc2(x))
            x = self.bn2(x)
            x = torch.sigmoid(self.fc3(x))
            return x
    
    


    class EarlyStopping:
        
        def __init__(self, patience=10, mode="min", delta=0.0, monitor="val_loss"):
            self.patience = patience
            self.counter = 0
            self.mode = mode
            self.best_score = None
            self.early_stop = False
            self.delta = delta
            self.monitor = monitor
            if self.mode == "min":
                self.val_score = np.Inf
            else:
                self.val_score = -np.Inf

        def __call__(self, epoch_score, model, model_path):

            if self.mode == "min":
                score = -1.0 * epoch_score
            else:
                score = np.copy(epoch_score)

            if self.best_score is None:
                self.best_score = score
                self.save_checkpoint(epoch_score, model, model_path)
            elif score < self.best_score + self.delta:
                self.counter += 1
                print(
                    f"EarlyStopping counter: {self.counter} out of {self.patience}"
                )
                if self.counter >= self.patience:
                    self.early_stop = True
            else:
                self.best_score = score
                self.save_checkpoint(epoch_score, model, model_path)
                self.counter = 0

        def save_checkpoint(self, epoch_score, model, model_path):
            """
            Saves model when validation loss decrease.
            """
            if epoch_score not in [-np.inf, np.inf, -np.nan, np.nan]:
                print(
                    f"Validation score improved ({self.val_score:.4f} --> {epoch_score:.4f}). Saving model!"
                )
                torch.save(model.state_dict(), model_path)
            self.val_score = epoch_score



    
    # Standardize the features
    a = StandardScaler()
    a.fit(X)
    X_standardized = a.transform(X)

    # Split the data into training and test sets
    X_train, X_test, y_train, y_test = train_test_split(X_standardized, y, test_size=0.3)
    X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
    X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
    y_test_tensor = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

    # Create DataLoader objects
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    # Create the model
    model = ANN()

    # Compile the model
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Use early stopping
    early_stop = EarlyStopping(patience=early_stop_patience)

    # Fit the PyTorch model on the dataset
    train_losses = []
    val_losses = []

    for epoch in range(epochs):
        model.train()
        running_loss = 0
        for inputs, targets in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        train_losses.append(running_loss / len(train_loader))

        model.eval()
        running_val_loss = 0
        with torch.no_grad():
            for inputs, targets in test_loader:
                outputs = model(inputs)
                val_loss = criterion(outputs, targets)
                running_val_loss += val_loss.item()

        val_losses.append(running_val_loss / len(test_loader))

        # Use early stopping to prevent overfitting
        early_stop(val_losses[-1], model, output_path)
        if early_stop.early_stop:
            print("Early stopping")
            break
    
    
    
    model.eval()
    y_pred_prob = model(X_test_tensor)
    #Convert the probabilities to class labels using a threshold (0.5 for binary classification)
    y_pred = (y_pred_prob.detach().numpy() > 0.5).astype(int)
    #Generate a classification report
    report = classification_report(y_test, y_pred, output_dict=True)

    # Save classification report to a text file
    report = classification_report(y_test, y_pred, output_dict=True)

    # Save classification report to a text file
    with open(f"final/{name}_classification_report.txt", 'w') as file:
        file.write('Classification Report:\n')
        for key, value in report.items():
            if isinstance(value, dict):  # if the value is a dictionary, write its keys and values too
                file.write(f'{key}:\n')
                for sub_key, sub_value in value.items():
                    file.write(f'  {sub_key}: {sub_value}\n')
            else:
                file.write(f'{key}: {value}\n')

    from sklearn.metrics import confusion_matrix
    import seaborn as sns

    # ...

    # Calculate ROC curve
    fpr, tpr, _ = roc_curve(y_test, y_pred)
    roc_auc = auc(fpr, tpr)

    # Plot ROC curve
    plt.figure(figsize=(8, 6))
    lw = 2
    plt.plot(fpr, tpr, color='darkorange', lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic curve')
    plt.legend(loc="lower right")
    plt.savefig(f"final/{name}_roc_curve.png")
    plt.show()

    # Calculate confusion matrix
    cm = confusion_matrix(y_test, y_pred)

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", xticklabels=["VF", "NotVF"], yticklabels=["VF", "NotVF"])
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.savefig(f"final/{name}_confusion_matrix.png")
    plt.show()

    # Plot the loss during training
    plt.figure(figsize=(8, 6))
    plt.title('Training and Validation Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.plot(train_losses, label='Train', color='blue')
    plt.plot(val_losses, label='Validation', color='orange')
    plt.legend()
    plt.tight_layout()
    plt.savefig(f"final/{name}_loss_activation_function={activation_function}_learning_rate={learning_rate}_neuron1={neuron1}_neuron1={neuron2}_epochs={epochs}_batch_size={batch_size}.png")
    plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt
from scipy import interp
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_auc_score

def neural_network_and_ROC(X, y, learning_rate=0.001, activation_function='relu', init='normal', neuron1=4, neuron2=2, epochs=1000, batch_size=20,name="you"):
    # Binarize the output
    print(y)
    y = label_binarize(y, classes=['NotVF', 'VF']).flatten()
    print(y)
    n_classes = 2
    
    accuracy_scores = []
    precision_scores = []
    specificity_scores = []
    recall_scores=[]
    
    cv = StratifiedKFold(n_splits=10,shuffle=True,random_state=1)
    tprs = []
    aucs = []
    mean_fpr = np.linspace(0, 1, 100)
    auces=[]
    plt.figure(figsize=(8, 6))

    for i, (train, test) in enumerate(cv.split(X, y)):
        # Calling the neural_network function you provided
        accuracy, precision, recall, f1, kappa, auc_score, model, y_pred_prob = neural_networkcv(X[train], y[train], X[test], y[test], learning_rate, activation_function, init, neuron1, neuron2, epochs, batch_size)
        # Compute ROC curve and area the curve
        fpr, tpr, thresholds = roc_curve(y[test], y_pred_prob)
        tprs.append(np.interp(mean_fpr, fpr, tpr))
        tprs[-1][0] = 0.0
        roc_auc = auc(fpr, tpr)
        aucs.append(roc_auc)
        roc_auc_percentage = roc_auc * 100
        plt.plot(fpr, tpr, lw=1, alpha=0.3,
                 label='ROC fold %d (AUC = %0.2f%%)' % (i, roc_auc_percentage))

        accuracy_scores.append(accuracy)
        precision_scores.append(precision)
        recall_scores.append(recall)
        auces.append(roc_auc)


        # Convert predicted probabilities to class labels
        threshold = 0.5
        y_pred = (y_pred_prob > threshold).astype(int)

        # Calculate specificity (True Negative Rate)
        tn, fp, fn, tp = confusion_matrix(y[test], y_pred).ravel()
        specificity = tn / (tn+fp)
        specificity_scores.append(specificity)



    plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
             label='Luck', alpha=.8)

    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = np.mean(auces)
    std_auc = np.std(aucs)
    mean_auc_percentage = mean_auc * 100
    std_auc_percentage = std_auc * 100
    plt.plot(mean_fpr, mean_tpr, color='b',
             label=r'Mean ROC (AUC = %0.2f%% $\pm$ %0.2f%%)' % (mean_auc_percentage, std_auc_percentage),
             lw=2, alpha=.4)

    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic curves')
    plt.legend(loc="lower right")

    plt.savefig(f"final/{name}_cv_roc")
    plt.show()

    

    # Plot Bar Charts
    import matplotlib.cm as cm
    from matplotlib.ticker import PercentFormatter


    folds = range(1, len(accuracy_scores) + 1)

    # Normalize the scores to range [0,1]
    def normalize_scores(scores):
        min_score = min(scores)
        max_score = max(scores)
        return [(score-min_score)/(max_score-min_score) for score in scores]

    plt.figure(figsize=(20,20))

    # Create color map
    color_map = cm.get_cmap('YlGnBu')

    # Calculate the color intensities for each metric
    accuracy_color_intensities = normalize_scores(accuracy_scores)
    precision_color_intensities = normalize_scores(precision_scores)
    recall_color_intensities = normalize_scores(recall_scores)
    specificity_color_intensities = normalize_scores(specificity_scores)

    plt.subplot(2,2,1)
    plt.bar(folds, accuracy_scores, edgecolor='k', color=color_map(accuracy_color_intensities))
    plt.title('Accuracy Scores')
    plt.xlabel('Fold')
    plt.ylabel('Accuracy')
    mean_accuracy = np.mean(accuracy_scores)
    mean_accuracy_percentage = mean_accuracy * 100
    plt.axhline(y=mean_accuracy, color='r', linestyle='--')
    plt.legend([f'Mean: {mean_accuracy_percentage:.2f}%'])

    plt.subplot(2,2,2)
    plt.bar(folds, precision_scores, edgecolor='k', color=color_map(precision_color_intensities))
    plt.title('Precision Scores')
    plt.xlabel('Fold')
    plt.ylabel('Precision')
    mean_precision = np.mean(precision_scores)
    mean_precision_percentage = mean_precision * 100
    plt.axhline(y=mean_precision, color='r', linestyle='--')
    plt.legend([f'Mean: {mean_precision_percentage:.2f}%'])

    plt.subplot(2,2,3)
    plt.bar(folds, recall_scores, edgecolor='k', color=color_map(recall_color_intensities))
    plt.title('Recall Scores')
    plt.xlabel('Fold')
    plt.ylabel('Recall')
    mean_recall = np.mean(recall_scores)
    mean_recall_percentage = mean_recall * 100
    plt.axhline(y=mean_recall, color='r', linestyle='--')
    plt.legend([f'Mean: {mean_recall_percentage:.2f}%'])

    plt.subplot(2,2,4)
    plt.bar(folds, specificity_scores, edgecolor='k', color=color_map(specificity_color_intensities))
    plt.title('Specificity Scores')
    plt.xlabel('Fold')
    plt.ylabel('Specificity')
    mean_specificity = np.mean(specificity_scores)
    mean_specificity_percentage = mean_specificity * 100
    plt.axhline(y=mean_specificity, color='r', linestyle='--')
    plt.legend([f'Mean: {mean_specificity_percentage:.2f}%'])

    # Set y-axis ticks as percentages
    plt.gca().yaxis.set_major_formatter(PercentFormatter(1))

    plt.tight_layout()
    plt.savefig(f"final/{name}_cv_metrics")
    plt.show()


"""
        
def neural_networkcv(X_train, y_train, X_test, y_test, learning_rate=0.001, activation_function='relu', init='normal', neuron1=4, neuron2=2, epochs=1000, batch_size=20):
    
    
    class ANN(nn.Module):
        def __init__(self, input_dim,activation_function, init, neuron1, neuron2):
            super(ANN, self).__init__()

            activation_functions = {
                'relu': nn.ReLU(),
                'tanh': nn.Tanh(),
                'sigmoid': nn.Sigmoid(),
                'softmax': nn.Softmax(dim=1)
            }

            init_methods = {
                'normal': nn.init.normal_,
                'uniform': nn.init.uniform_,
                'xavier': nn.init.xavier_uniform_
            }

            self.activation_function = activation_functions[activation_function]

            self.fc1 = nn.Linear(input_dim, neuron1)
            init_methods[init](self.fc1.weight)

            self.fc2 = nn.Linear(neuron1, neuron2)
            init_methods[init](self.fc2.weight)

            self.fc3 = nn.Linear(neuron2, 1)
            init_methods[init](self.fc3.weight)

            self.bn1 = nn.BatchNorm1d(neuron1)
            self.bn2 = nn.BatchNorm1d(neuron2)

        def forward(self, x):
            x = self.activation_function(self.fc1(x))
            x = self.bn1(x)
            x = self.activation_function(self.fc2(x))
            x = self.bn2(x)
            x = torch.sigmoid(self.fc3(x))
            return x
    
    
    # Get the number of features (input dimension) from X
    input_dim = X_train.shape[1]

    # Instantiate the encoder
    le = LabelEncoder()

    # Fit and transform the target variable y
    y_train = le.fit_transform(y_train)
    y_test = le.transform(y_test)

    # Standardize the features
    a = StandardScaler()
    a.fit(X_train)
    X_train_standardized = a.transform(X_train)

    X_test_standardized = a.transform(X_test)

    X_train_tensor = torch.tensor(X_train_standardized, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
    X_test_tensor = torch.tensor(X_test_standardized, dtype=torch.float32)
    y_test_tensor = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

    # Create DataLoader objects
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    # Create the model
    model = ANN(input_dim=input_dim, activation_function=activation_function, init=init, neuron1=neuron1, neuron2=neuron2)

    # Compile the model
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Fit the PyTorch model on the dataset
    train_losses = []
    val_losses = []

    for epoch in range(epochs):
        model.train()
        running_loss = 0
        for inputs, targets in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        train_losses.append(running_loss / len(train_loader))

        model.eval()
        running_val_loss = 0
        with torch.no_grad():
            for inputs, targets in test_loader:
                outputs = model(inputs)
                val_loss = criterion(outputs, targets)
                running_val_loss += val_loss.item()

        val_losses.append(running_val_loss / len(test_loader))

    # Evaluate the model
    model.eval()
    y_pred_prob = model(X_test_tensor)

    # Convert the probabilities to class labels using a threshold (0.5 for binary classification)
    y_pred = (y_pred_prob.detach().numpy() > 0.5).astype(int)

    # Calculate and return the metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    kappa = cohen_kappa_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_pred)

    return accuracy, precision, recall, f1, kappa, auc, model, y_pred_prob.detach().numpy()

"""


def neural_networkcv(X_train, y_train, X_test, y_test, learning_rate=0.001, activation_function='relu', init='normal', neuron1=4, neuron2=2, epochs=1000, batch_size=20, early_stop_patience=10,output_path='model.pt'):
    class ANN(nn.Module):
        def __init__(self, input_dim, activation_function, init, neuron1, neuron2):
            super(ANN, self).__init__()

            activation_functions = {
                'relu': nn.ReLU(),
                'tanh': nn.Tanh(),
                'sigmoid': nn.Sigmoid(),
                'softmax': nn.Softmax(dim=1)
            }

            init_methods = {
                'normal': nn.init.normal_,
                'uniform': nn.init.uniform_,
                'xavier': nn.init.xavier_uniform_
            }

            self.activation_function = activation_functions[activation_function]

            self.fc1 = nn.Linear(input_dim, neuron1)
            init_methods[init](self.fc1.weight)

            self.fc2 = nn.Linear(neuron1, neuron2)
            init_methods[init](self.fc2.weight)

            self.fc3 = nn.Linear(neuron2, 1)
            init_methods[init](self.fc3.weight)

            self.bn1 = nn.BatchNorm1d(neuron1)
            self.bn2 = nn.BatchNorm1d(neuron2)

        def forward(self, x):
            x = self.activation_function(self.fc1(x))
            x = self.bn1(x)
            x = self.activation_function(self.fc2(x))
            x = self.bn2(x)
            x = torch.sigmoid(self.fc3(x))
            return x

    # Get the number of features (input dimension) from X
    input_dim = X_train.shape[1]

    # Instantiate the encoder
    le = LabelEncoder()

    # Fit and transform the target variable y
    y_train = le.fit_transform(y_train)
    y_test = le.transform(y_test)

    # Standardize the features
    a = StandardScaler()
    a.fit(X_train)
    X_train_standardized = a.transform(X_train)

    X_test_standardized = a.transform(X_test)

    X_train_tensor = torch.tensor(X_train_standardized, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
    X_test_tensor = torch.tensor(X_test_standardized, dtype=torch.float32)
    y_test_tensor = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

    # Create DataLoader objects
    train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

    test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    class EarlyStopping:
        def __init__(self, patience=10, mode="min", delta=0.0, monitor="val_loss"):
            self.patience = patience
            self.counter = 0
            self.mode = mode
            self.best_score = None
            self.early_stop = False
            self.delta = delta
            self.monitor = monitor
            if self.mode == "min":
                self.val_score = np.Inf
            else:
                self.val_score = -np.Inf

        def __call__(self, epoch_score, model, model_path):
            if self.mode == "min":
                score = -1.0 * epoch_score
            else:
                score = np.copy(epoch_score)
            if self.best_score is None:
                self.best_score = score
                self.save_checkpoint(epoch_score, model, model_path)
            elif score < self.best_score + self.delta:
                self.counter += 1
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
                if self.counter >= self.patience:
                    self.early_stop = True
            else:
                self.best_score = score
                self.save_checkpoint(epoch_score, model, model_path)
                self.counter = 0

        def save_checkpoint(self, epoch_score, model, model_path):
            if epoch_score not in [-np.inf, np.inf, -np.nan, np.nan]:
                print(
                    f"Validation score improved ({self.val_score:.4f} --> {epoch_score:.4f}). Saving model!"
                )
                torch.save(model.state_dict(), model_path)
            self.val_score = epoch_score

                # Create the model
    model = ANN(input_dim=input_dim, activation_function=activation_function, init=init, neuron1=neuron1, neuron2=neuron2)

    # Compile the model
    criterion = nn.BCELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Use early stopping
    early_stop = EarlyStopping(patience=early_stop_patience)

    # Fit the PyTorch model on the dataset
    train_losses = []
    val_losses = []

    for epoch in range(epochs):
        model.train()
        running_loss = 0
        for inputs, targets in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        train_losses.append(running_loss / len(train_loader))

        model.eval()
        running_val_loss = 0
        with torch.no_grad():
            for inputs, targets in test_loader:
                outputs = model(inputs)
                val_loss = criterion(outputs, targets)
                running_val_loss += val_loss.item()

        val_losses.append(running_val_loss / len(test_loader))

        # Use early stopping to prevent overfitting
        early_stop(val_losses[-1], model, output_path)
        if early_stop.early_stop:
            print("Early stopping")
            break

    # Evaluate the model
    model.eval()
    y_pred_prob = model(X_test_tensor)

    # Convert the probabilities to class labels using a threshold (0.5 for binary classification)
    y_pred = (y_pred_prob.detach().numpy() > 0.5).astype(int)

    # Calculate and return the metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    kappa = cohen_kappa_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_pred)

    return accuracy, precision, recall, f1, kappa, auc, model, y_pred_prob.detach().numpy()

# %% [markdown]
# # Best parametre all shape

# %%
# define dataset
X1=df[['RDAmpM','RDAmpSD', 'QRsa', 'QRaSD',"pos_area","neg_area"]]
y1=df["label"]
X,y=smooth(X1,y1)
X_array = X.values
y_array = y.values.ravel()
# Out:
# Counter({'NotVF': 88487, 'VF': 6741})
# Counter({'NotVF': 88487, 'VF': 88487})

# %%
learning_rate= [0.0001]
activation_function=['tanh']
init=['uniform']
neuron1=[128]
neuron2=[64]
epochs=[5]
batch_size=[100]

for lr in learning_rate:
    for af in activation_function:
        for init_mode in init:
            for n1 in neuron1:
                for n2 in neuron2:
                    for ep in epochs:
                        for bs in batch_size:
                            print(f"Running model with learning_rate={lr}, activation_function={af}, init={init_mode}, neuron1={n1}, neuron2={n2}, epochs={ep}, batch_size={bs}")
                            neural_network(X, y, learning_rate=lr, activation_function=af, init=init_mode, neuron1=n1, neuron2=n2, epochs=ep, batch_size=bs, output_path="model.pt",name="all_shape")
# Out:
# Running model with learning_rate=0.0001, activation_function=tanh, init=uniform, neuron1=128, neuron2=64, epochs=5, batch_size=100
# Validation score improved (inf --> 24.1873). Saving model!
# Validation score improved (24.1873 --> 15.7154). Saving model!
# Validation score improved (15.7154 --> 7.0730). Saving model!
# Validation score improved (7.0730 --> 2.7265). Saving model!
# Validation score improved (2.7265 --> 1.6888). Saving model!

# %%
learning_rate= [0.0001]
activation_function=['tanh']
init=['uniform']
neuron1=[128]
neuron2=[64]
epochs=[1000]
batch_size=[100]

for lr in learning_rate:
    for af in activation_function:
        for init_mode in init:
            for n1 in neuron1:
                for n2 in neuron2:
                    for ep in epochs:
                        for bs in batch_size:
                            print(f"Running model with learning_rate={lr}, activation_function={af}, init={init_mode}, neuron1={n1}, neuron2={n2}, epochs={ep}, batch_size={bs}")
                            neural_network_and_ROC(X_array, y_array, learning_rate=lr, activation_function=af, init=init_mode, neuron1=n1, neuron2=n2, epochs=ep, batch_size=bs,name='CV_allshape')
# Out:
# Running model with learning_rate=0.0001, activation_function=tanh, init=uniform, neuron1=128, neuron2=64, epochs=1000, batch_size=100
# ['NotVF' 'NotVF' 'NotVF' ... 'VF' 'VF' 'VF']
# [0 0 0 ... 1 1 1]
# Validation score improved (inf --> 18.5490). Saving model!
# Validation score improved (18.5490 --> 5.6052). Saving model!
# Validation score improved (5.6052 --> 1.2501). Saving model!
# Validation score improved (1.2501 --> 0.4184). Saving model!
# Validation score improved (0.4184 --> 0.3349). Saving model!
# Validation score improved (0.3349 --> 0.2876). Saving model!
# Validation score improved (0.2876 --> 0.2514). Saving model!
# Validation score improved (0.2514 --> 0.2245). Saving model!
# Validation score improved (0.2245 --> 0.1992). Saving model!
# Validation score improved (0.1992 --> 0.1788). Saving model!
# Validation score improved (0.1788 --> 0.1695). Saving model!
# Validation score improved (0.1695 --> 0.1623). Saving model!
# Validation score improved (0.1623 --> 0.1593). Saving model!
# Validation score improved (0.1593 --> 0.1524). Saving model!
# Validation score improved (0.1524 --> 0.1481). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1481 --> 0.1435). Saving model!
# Validation score improved (0.1435 --> 0.1428). Saving model!
# Validation score improved (0.1428 --> 0.1395). Saving model!
# Validation score improved (0.1395 --> 0.1355). Saving model!
# Validation score improved (0.1355 --> 0.1346). Saving model!
# Validation score improved (0.1346 --> 0.1327). Saving model!
# Validation score improved (0.1327 --> 0.1297). Saving model!
# Validation score improved (0.1297 --> 0.1281). Saving model!
# Validation score improved (0.1281 --> 0.1251). Saving model!
# Validation score improved (0.1251 --> 0.1241). Saving model!
# Validation score improved (0.1241 --> 0.1235). Saving model!
# Validation score improved (0.1235 --> 0.1214). Saving model!
# Validation score improved (0.1214 --> 0.1206). Saving model!
# Validation score improved (0.1206 --> 0.1185). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1185 --> 0.1174). Saving model!
# Validation score improved (0.1174 --> 0.1152). Saving model!
# Validation score improved (0.1152 --> 0.1139). Saving model!
# Validation score improved (0.1139 --> 0.1135). Saving model!
# Validation score improved (0.1135 --> 0.1122). Saving model!
# Validation score improved (0.1122 --> 0.1115). Saving model!
# Validation score improved (0.1115 --> 0.1100). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1100 --> 0.1081). Saving model!
# Validation score improved (0.1081 --> 0.1071). Saving model!
# Validation score improved (0.1071 --> 0.1070). Saving model!
# Validation score improved (0.1070 --> 0.1065). Saving model!
# Validation score improved (0.1065 --> 0.1058). Saving model!
# Validation score improved (0.1058 --> 0.1040). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.1040 --> 0.1001). Saving model!
# Validation score improved (0.1001 --> 0.0996). Saving model!
# Validation score improved (0.0996 --> 0.0992). Saving model!
# Validation score improved (0.0992 --> 0.0991). Saving model!
# Validation score improved (0.0991 --> 0.0982). Saving model!
# Validation score improved (0.0982 --> 0.0968). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0968 --> 0.0961). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0961 --> 0.0949). Saving model!
# Validation score improved (0.0949 --> 0.0945). Saving model!
# Validation score improved (0.0945 --> 0.0940). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0940 --> 0.0932). Saving model!
# Validation score improved (0.0932 --> 0.0929). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0929 --> 0.0929). Saving model!
# Validation score improved (0.0929 --> 0.0924). Saving model!
# Validation score improved (0.0924 --> 0.0915). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0915 --> 0.0902). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0902 --> 0.0891). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0891 --> 0.0883). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0883 --> 0.0876). Saving model!
# Validation score improved (0.0876 --> 0.0875). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0875 --> 0.0865). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0865 --> 0.0860). Saving model!
# Validation score improved (0.0860 --> 0.0859). Saving model!
# Validation score improved (0.0859 --> 0.0851). Saving model!
# Validation score improved (0.0851 --> 0.0845). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0845 --> 0.0843). Saving model!
# Validation score improved (0.0843 --> 0.0832). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0832 --> 0.0830). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0830 --> 0.0821). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0821 --> 0.0817). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0817 --> 0.0811). Saving model!
# Validation score improved (0.0811 --> 0.0806). Saving model!
# Validation score improved (0.0806 --> 0.0804). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0804 --> 0.0802). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0802 --> 0.0799). Saving model!
# Validation score improved (0.0799 --> 0.0797). Saving model!
# Validation score improved (0.0797 --> 0.0794). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0794 --> 0.0790). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0790 --> 0.0786). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0786 --> 0.0779). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0779 --> 0.0776). Saving model!
# Validation score improved (0.0776 --> 0.0775). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0775 --> 0.0773). Saving model!
# Validation score improved (0.0773 --> 0.0765). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0765 --> 0.0758). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0758 --> 0.0751). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0751 --> 0.0745). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0745 --> 0.0743). Saving model!
# Validation score improved (0.0743 --> 0.0743). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0743 --> 0.0731). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0731 --> 0.0726). Saving model!
# Validation score improved (0.0726 --> 0.0725). Saving model!
# Validation score improved (0.0725 --> 0.0723). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0723 --> 0.0719). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0719 --> 0.0710). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0710 --> 0.0710). Saving model!
# Validation score improved (0.0710 --> 0.0709). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0709 --> 0.0705). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0705 --> 0.0698). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0698 --> 0.0697). Saving model!
# Validation score improved (0.0697 --> 0.0696). Saving model!
# Validation score improved (0.0696 --> 0.0696). Saving model!
# Validation score improved (0.0696 --> 0.0690). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0690 --> 0.0684). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0684 --> 0.0680). Saving model!
# Validation score improved (0.0680 --> 0.0677). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0677 --> 0.0675). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0675 --> 0.0674). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0674 --> 0.0672). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0672 --> 0.0664). Saving model!
# Validation score improved (0.0664 --> 0.0663). Saving model!
# Validation score improved (0.0663 --> 0.0659). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0659 --> 0.0656). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0656 --> 0.0656). Saving model!
# Validation score improved (0.0656 --> 0.0654). Saving model!
# Validation score improved (0.0654 --> 0.0653). Saving model!
# Validation score improved (0.0653 --> 0.0652). Saving model!
# Validation score improved (0.0652 --> 0.0651). Saving model!
# Validation score improved (0.0651 --> 0.0647). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0647 --> 0.0645). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0645 --> 0.0640). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0640 --> 0.0637). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0637 --> 0.0636). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0636 --> 0.0631). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0631 --> 0.0631). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0631 --> 0.0628). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0628 --> 0.0626). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0626 --> 0.0623). Saving model!
# Validation score improved (0.0623 --> 0.0623). Saving model!
# Validation score improved (0.0623 --> 0.0620). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0620 --> 0.0618). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0618 --> 0.0618). Saving model!
# Validation score improved (0.0618 --> 0.0615). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0615 --> 0.0613). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# Validation score improved (0.0613 --> 0.0610). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0610 --> 0.0609). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0609 --> 0.0607). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0607 --> 0.0605). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0605 --> 0.0599). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# Validation score improved (0.0599 --> 0.0597). Saving model!
# Validation score improved (0.0597 --> 0.0597). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0597 --> 0.0593). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping
# Validation score improved (inf --> 19.3034). Saving model!
# Validation score improved (19.3034 --> 6.9562). Saving model!
# Validation score improved (6.9562 --> 0.6327). Saving model!
# Validation score improved (0.6327 --> 0.3967). Saving model!
# Validation score improved (0.3967 --> 0.3036). Saving model!
# Validation score improved (0.3036 --> 0.2641). Saving model!
# Validation score improved (0.2641 --> 0.2351). Saving model!
# Validation score improved (0.2351 --> 0.2140). Saving model!
# Validation score improved (0.2140 --> 0.1943). Saving model!
# Validation score improved (0.1943 --> 0.1785). Saving model!
# Validation score improved (0.1785 --> 0.1662). Saving model!
# Validation score improved (0.1662 --> 0.1578). Saving model!
# Validation score improved (0.1578 --> 0.1558). Saving model!
# Validation score improved (0.1558 --> 0.1493). Saving model!
# Validation score improved (0.1493 --> 0.1480). Saving model!
# Validation score improved (0.1480 --> 0.1433). Saving model!
# Validation score improved (0.1433 --> 0.1412). Saving model!
# Validation score improved (0.1412 --> 0.1391). Saving model!
# Validation score improved (0.1391 --> 0.1388). Saving model!
# Validation score improved (0.1388 --> 0.1341). Saving model!
# Validation score improved (0.1341 --> 0.1332). Saving model!
# Validation score improved (0.1332 --> 0.1323). Saving model!
# Validation score improved (0.1323 --> 0.1303). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1303 --> 0.1276). Saving model!
# Validation score improved (0.1276 --> 0.1271). Saving model!
# Validation score improved (0.1271 --> 0.1265). Saving model!
# Validation score improved (0.1265 --> 0.1242). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.1242 --> 0.1198). Saving model!
# Validation score improved (0.1198 --> 0.1188). Saving model!
# Validation score improved (0.1188 --> 0.1169). Saving model!
# Validation score improved (0.1169 --> 0.1158). Saving model!
# Validation score improved (0.1158 --> 0.1151). Saving model!
# Validation score improved (0.1151 --> 0.1130). Saving model!
# Validation score improved (0.1130 --> 0.1119). Saving model!
# Validation score improved (0.1119 --> 0.1111). Saving model!
# Validation score improved (0.1111 --> 0.1082). Saving model!
# Validation score improved (0.1082 --> 0.1077). Saving model!
# Validation score improved (0.1077 --> 0.1069). Saving model!
# Validation score improved (0.1069 --> 0.1066). Saving model!
# Validation score improved (0.1066 --> 0.1053). Saving model!
# Validation score improved (0.1053 --> 0.1053). Saving model!
# Validation score improved (0.1053 --> 0.1034). Saving model!
# Validation score improved (0.1034 --> 0.1016). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1016 --> 0.1006). Saving model!
# Validation score improved (0.1006 --> 0.0989). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0989 --> 0.0988). Saving model!
# Validation score improved (0.0988 --> 0.0984). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0984 --> 0.0973). Saving model!
# Validation score improved (0.0973 --> 0.0969). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0969 --> 0.0939). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0939 --> 0.0931). Saving model!
# Validation score improved (0.0931 --> 0.0930). Saving model!
# Validation score improved (0.0930 --> 0.0919). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0919 --> 0.0915). Saving model!
# Validation score improved (0.0915 --> 0.0898). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0898 --> 0.0887). Saving model!
# Validation score improved (0.0887 --> 0.0882). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0882 --> 0.0878). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0878 --> 0.0862). Saving model!
# Validation score improved (0.0862 --> 0.0860). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0860 --> 0.0849). Saving model!
# Validation score improved (0.0849 --> 0.0848). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0848 --> 0.0838). Saving model!
# Validation score improved (0.0838 --> 0.0833). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0833 --> 0.0826). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0826 --> 0.0824). Saving model!
# Validation score improved (0.0824 --> 0.0821). Saving model!
# Validation score improved (0.0821 --> 0.0812). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0812 --> 0.0807). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0807 --> 0.0804). Saving model!
# Validation score improved (0.0804 --> 0.0803). Saving model!
# Validation score improved (0.0803 --> 0.0801). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0801 --> 0.0795). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0795 --> 0.0784). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0784 --> 0.0781). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0781 --> 0.0776). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0776 --> 0.0773). Saving model!
# Validation score improved (0.0773 --> 0.0768). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0768 --> 0.0767). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0767 --> 0.0764). Saving model!
# Validation score improved (0.0764 --> 0.0763). Saving model!
# Validation score improved (0.0763 --> 0.0759). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0759 --> 0.0749). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0749 --> 0.0747). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# Validation score improved (0.0747 --> 0.0735). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0735 --> 0.0734). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0734 --> 0.0731). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0731 --> 0.0727). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0727 --> 0.0722). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0722 --> 0.0717). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0717 --> 0.0710). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# Validation score improved (0.0710 --> 0.0705). Saving model!
# Validation score improved (0.0705 --> 0.0704). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0704 --> 0.0700). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0700 --> 0.0693). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# Validation score improved (0.0693 --> 0.0683). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# Validation score improved (0.0683 --> 0.0681). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0681 --> 0.0678). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0678 --> 0.0673). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# Validation score improved (0.0673 --> 0.0669). Saving model!
# Validation score improved (0.0669 --> 0.0666). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0666 --> 0.0663). Saving model!
# Validation score improved (0.0663 --> 0.0662). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0662 --> 0.0661). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0661 --> 0.0661). Saving model!
# Validation score improved (0.0661 --> 0.0660). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0660 --> 0.0656). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0656 --> 0.0653). Saving model!
# Validation score improved (0.0653 --> 0.0650). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# Validation score improved (0.0650 --> 0.0645). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# Validation score improved (0.0645 --> 0.0641). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# Validation score improved (0.0641 --> 0.0637). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0637 --> 0.0633). Saving model!
# Validation score improved (0.0633 --> 0.0633). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0633 --> 0.0631). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0631 --> 0.0630). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0630 --> 0.0629). Saving model!
# Validation score improved (0.0629 --> 0.0625). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0625 --> 0.0624). Saving model!
# Validation score improved (0.0624 --> 0.0619). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0619 --> 0.0615). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# Validation score improved (0.0615 --> 0.0614). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# Validation score improved (0.0614 --> 0.0606). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping
# Validation score improved (inf --> 21.4023). Saving model!
# Validation score improved (21.4023 --> 7.5064). Saving model!
# Validation score improved (7.5064 --> 1.4477). Saving model!
# Validation score improved (1.4477 --> 0.4372). Saving model!
# Validation score improved (0.4372 --> 0.3522). Saving model!
# Validation score improved (0.3522 --> 0.2973). Saving model!
# Validation score improved (0.2973 --> 0.2546). Saving model!
# Validation score improved (0.2546 --> 0.2263). Saving model!
# Validation score improved (0.2263 --> 0.2054). Saving model!
# Validation score improved (0.2054 --> 0.1846). Saving model!
# Validation score improved (0.1846 --> 0.1708). Saving model!
# Validation score improved (0.1708 --> 0.1627). Saving model!
# Validation score improved (0.1627 --> 0.1599). Saving model!
# Validation score improved (0.1599 --> 0.1501). Saving model!
# Validation score improved (0.1501 --> 0.1474). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1474 --> 0.1447). Saving model!
# Validation score improved (0.1447 --> 0.1404). Saving model!
# Validation score improved (0.1404 --> 0.1379). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1379 --> 0.1334). Saving model!
# Validation score improved (0.1334 --> 0.1319). Saving model!
# Validation score improved (0.1319 --> 0.1296). Saving model!
# Validation score improved (0.1296 --> 0.1279). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1279 --> 0.1245). Saving model!
# Validation score improved (0.1245 --> 0.1230). Saving model!
# Validation score improved (0.1230 --> 0.1220). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1220 --> 0.1205). Saving model!
# Validation score improved (0.1205 --> 0.1176). Saving model!
# Validation score improved (0.1176 --> 0.1166). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1166 --> 0.1144). Saving model!
# Validation score improved (0.1144 --> 0.1136). Saving model!
# Validation score improved (0.1136 --> 0.1132). Saving model!
# Validation score improved (0.1132 --> 0.1114). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1114 --> 0.1099). Saving model!
# Validation score improved (0.1099 --> 0.1078). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1078 --> 0.1075). Saving model!
# Validation score improved (0.1075 --> 0.1065). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1065 --> 0.1044). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.1044 --> 0.1029). Saving model!
# Validation score improved (0.1029 --> 0.1025). Saving model!
# Validation score improved (0.1025 --> 0.1016). Saving model!
# Validation score improved (0.1016 --> 0.1011). Saving model!
# Validation score improved (0.1011 --> 0.1009). Saving model!
# Validation score improved (0.1009 --> 0.1005). Saving model!
# Validation score improved (0.1005 --> 0.0991). Saving model!
# Validation score improved (0.0991 --> 0.0990). Saving model!
# Validation score improved (0.0990 --> 0.0986). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0986 --> 0.0985). Saving model!
# Validation score improved (0.0985 --> 0.0978). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0978 --> 0.0974). Saving model!
# Validation score improved (0.0974 --> 0.0968). Saving model!
# Validation score improved (0.0968 --> 0.0960). Saving model!
# Validation score improved (0.0960 --> 0.0956). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0956 --> 0.0951). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0951 --> 0.0947). Saving model!
# Validation score improved (0.0947 --> 0.0940). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0940 --> 0.0938). Saving model!
# Validation score improved (0.0938 --> 0.0932). Saving model!
# Validation score improved (0.0926 --> 0.0924). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0924 --> 0.0908). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0908 --> 0.0901). Saving model!
# Validation score improved (0.0901 --> 0.0896). Saving model!
# Validation score improved (0.0896 --> 0.0891). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0891 --> 0.0885). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0885 --> 0.0878). Saving model!
# Validation score improved (0.0878 --> 0.0874). Saving model!
# Validation score improved (0.0874 --> 0.0867). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0867 --> 0.0857). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0857 --> 0.0852). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0852 --> 0.0850). Saving model!
# Validation score improved (0.0850 --> 0.0845). Saving model!
# Validation score improved (0.0845 --> 0.0843). Saving model!
# Validation score improved (0.0843 --> 0.0840). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0840 --> 0.0835). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0835 --> 0.0827). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0827 --> 0.0827). Saving model!
# Validation score improved (0.0827 --> 0.0824). Saving model!
# Validation score improved (0.0824 --> 0.0813). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0813 --> 0.0809). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# Validation score improved (0.0809 --> 0.0804). Saving model!
# Validation score improved (0.0804 --> 0.0800). Saving model!
# Validation score improved (0.0800 --> 0.0798). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0798 --> 0.0794). Saving model!
# Validation score improved (0.0794 --> 0.0790). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0790 --> 0.0784). Saving model!
# Validation score improved (0.0784 --> 0.0782). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0782 --> 0.0779). Saving model!
# Validation score improved (0.0779 --> 0.0779). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0779 --> 0.0776). Saving model!
# Validation score improved (0.0776 --> 0.0772). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0772 --> 0.0767). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0767 --> 0.0764). Saving model!
# Validation score improved (0.0764 --> 0.0764). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0764 --> 0.0761). Saving model!
# Validation score improved (0.0761 --> 0.0758). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0758 --> 0.0748). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# Validation score improved (0.0748 --> 0.0743). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0743 --> 0.0734). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0734 --> 0.0733). Saving model!
# Validation score improved (0.0733 --> 0.0732). Saving model!
# Validation score improved (0.0732 --> 0.0732). Saving model!
# Validation score improved (0.0732 --> 0.0730). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0730 --> 0.0728). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0728 --> 0.0724). Saving model!
# Validation score improved (0.0724 --> 0.0722). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0722 --> 0.0718). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0718 --> 0.0717). Saving model!
# Validation score improved (0.0717 --> 0.0715). Saving model!
# Validation score improved (0.0715 --> 0.0711). Saving model!
# Validation score improved (0.0711 --> 0.0705). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0705 --> 0.0702). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0702 --> 0.0701). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0701 --> 0.0697). Saving model!
# Validation score improved (0.0697 --> 0.0695). Saving model!
# Validation score improved (0.0695 --> 0.0693). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0693 --> 0.0683). Saving model!
# Validation score improved (0.0683 --> 0.0683). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0683 --> 0.0680). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0680 --> 0.0680). Saving model!
# Validation score improved (0.0680 --> 0.0678). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0678 --> 0.0674). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0674 --> 0.0669). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# Validation score improved (0.0669 --> 0.0666). Saving model!
# Validation score improved (0.0666 --> 0.0666). Saving model!
# Validation score improved (0.0666 --> 0.0664). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0664 --> 0.0664). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0664 --> 0.0662). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0662 --> 0.0652). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# Validation score improved (0.0652 --> 0.0648). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# Validation score improved (0.0648 --> 0.0647). Saving model!
# Validation score improved (0.0647 --> 0.0644). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0644 --> 0.0642). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0642 --> 0.0642). Saving model!
# Validation score improved (0.0642 --> 0.0638). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# Validation score improved (0.0638 --> 0.0632). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0632 --> 0.0630). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# Validation score improved (0.0630 --> 0.0628). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0628 --> 0.0628). Saving model!
# Validation score improved (0.0628 --> 0.0626). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0626 --> 0.0626). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# Validation score improved (0.0626 --> 0.0619). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# Validation score improved (0.0619 --> 0.0617). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0617 --> 0.0615). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0615 --> 0.0615). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0615 --> 0.0615). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0615 --> 0.0613). Saving model!
# Validation score improved (0.0613 --> 0.0611). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# Validation score improved (0.0611 --> 0.0611). Saving model!
# Validation score improved (0.0611 --> 0.0610). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0610 --> 0.0607). Saving model!
# Validation score improved (0.0607 --> 0.0606). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# Validation score improved (0.0606 --> 0.0603). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# Validation score improved (0.0603 --> 0.0600). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0600 --> 0.0598). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping
# Validation score improved (inf --> 21.2601). Saving model!
# Validation score improved (21.2601 --> 9.3938). Saving model!
# Validation score improved (9.3938 --> 3.5237). Saving model!
# Validation score improved (3.5237 --> 1.7018). Saving model!
# Validation score improved (1.7018 --> 0.8696). Saving model!
# Validation score improved (0.8696 --> 0.6036). Saving model!
# Validation score improved (0.6036 --> 0.4920). Saving model!
# Validation score improved (0.4920 --> 0.4154). Saving model!
# Validation score improved (0.4154 --> 0.3153). Saving model!
# Validation score improved (0.3153 --> 0.2217). Saving model!
# Validation score improved (0.2217 --> 0.1892). Saving model!
# Validation score improved (0.1892 --> 0.1751). Saving model!
# Validation score improved (0.1751 --> 0.1587). Saving model!
# Validation score improved (0.1587 --> 0.1536). Saving model!
# Validation score improved (0.1536 --> 0.1496). Saving model!
# Validation score improved (0.1496 --> 0.1439). Saving model!
# Validation score improved (0.1439 --> 0.1416). Saving model!
# Validation score improved (0.1416 --> 0.1409). Saving model!
# Validation score improved (0.1409 --> 0.1391). Saving model!
# Validation score improved (0.1391 --> 0.1366). Saving model!
# Validation score improved (0.1366 --> 0.1365). Saving model!
# Validation score improved (0.1365 --> 0.1348). Saving model!
# Validation score improved (0.1348 --> 0.1338). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1338 --> 0.1335). Saving model!
# Validation score improved (0.1335 --> 0.1313). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1313 --> 0.1271). Saving model!
# Validation score improved (0.1271 --> 0.1269). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1269 --> 0.1260). Saving model!
# Validation score improved (0.1260 --> 0.1237). Saving model!
# Validation score improved (0.1237 --> 0.1223). Saving model!
# Validation score improved (0.1223 --> 0.1220). Saving model!
# Validation score improved (0.1220 --> 0.1216). Saving model!
# Validation score improved (0.1216 --> 0.1206). Saving model!
# Validation score improved (0.1206 --> 0.1197). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1197 --> 0.1190). Saving model!
# Validation score improved (0.1190 --> 0.1182). Saving model!
# Validation score improved (0.1182 --> 0.1177). Saving model!
# Validation score improved (0.1177 --> 0.1171). Saving model!
# Validation score improved (0.1171 --> 0.1165). Saving model!
# Validation score improved (0.1165 --> 0.1154). Saving model!
# Validation score improved (0.1154 --> 0.1149). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1149 --> 0.1148). Saving model!
# Validation score improved (0.1148 --> 0.1133). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1133 --> 0.1116). Saving model!
# Validation score improved (0.1116 --> 0.1112). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1112 --> 0.1106). Saving model!
# Validation score improved (0.1106 --> 0.1094). Saving model!
# Validation score improved (0.1094 --> 0.1090). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1090 --> 0.1086). Saving model!
# Validation score improved (0.1086 --> 0.1061). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1061 --> 0.1059). Saving model!
# Validation score improved (0.1059 --> 0.1041). Saving model!
# Validation score improved (0.1041 --> 0.1036). Saving model!
# Validation score improved (0.1036 --> 0.1031). Saving model!
# Validation score improved (0.1031 --> 0.1021). Saving model!
# Validation score improved (0.1021 --> 0.1015). Saving model!
# Validation score improved (0.1015 --> 0.1002). Saving model!
# Validation score improved (0.1002 --> 0.0997). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0997 --> 0.0989). Saving model!
# Validation score improved (0.0989 --> 0.0977). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0977 --> 0.0972). Saving model!
# Validation score improved (0.0972 --> 0.0963). Saving model!
# Validation score improved (0.0963 --> 0.0961). Saving model!
# Validation score improved (0.0961 --> 0.0953). Saving model!
# Validation score improved (0.0953 --> 0.0953). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0953 --> 0.0938). Saving model!
# Validation score improved (0.0938 --> 0.0936). Saving model!
# Validation score improved (0.0936 --> 0.0931). Saving model!
# Validation score improved (0.0931 --> 0.0927). Saving model!
# Validation score improved (0.0927 --> 0.0920). Saving model!
# ...
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# Validation score improved (0.0550 --> 0.0550). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0550 --> 0.0547). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0547 --> 0.0546). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0546 --> 0.0544). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# Validation score improved (0.0544 --> 0.0541). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0541 --> 0.0540). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# Validation score improved (0.0540 --> 0.0539). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0539 --> 0.0538). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0538 --> 0.0533). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping
# Validation score improved (inf --> 20.2957). Saving model!
# Validation score improved (20.2957 --> 1.2877). Saving model!
# Validation score improved (1.2877 --> 0.5645). Saving model!
# Validation score improved (0.5645 --> 0.3948). Saving model!
# Validation score improved (0.3948 --> 0.3288). Saving model!
# Validation score improved (0.3288 --> 0.2878). Saving model!
# Validation score improved (0.2878 --> 0.2599). Saving model!
# Validation score improved (0.2599 --> 0.2377). Saving model!
# Validation score improved (0.2377 --> 0.2137). Saving model!
# Validation score improved (0.2137 --> 0.1905). Saving model!
# Validation score improved (0.1905 --> 0.1798). Saving model!
# Validation score improved (0.1798 --> 0.1714). Saving model!
# Validation score improved (0.1714 --> 0.1661). Saving model!
# Validation score improved (0.1661 --> 0.1640). Saving model!
# Validation score improved (0.1640 --> 0.1621). Saving model!
# Validation score improved (0.1621 --> 0.1587). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.1587 --> 0.1544). Saving model!
# Validation score improved (0.1544 --> 0.1535). Saving model!
# Validation score improved (0.1535 --> 0.1505). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1505 --> 0.1495). Saving model!
# Validation score improved (0.1495 --> 0.1488). Saving model!
# Validation score improved (0.1488 --> 0.1462). Saving model!
# Validation score improved (0.1462 --> 0.1449). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1449 --> 0.1423). Saving model!
# Validation score improved (0.1423 --> 0.1406). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1406 --> 0.1393). Saving model!
# Validation score improved (0.1393 --> 0.1365). Saving model!
# Validation score improved (0.1365 --> 0.1351). Saving model!
# Validation score improved (0.1351 --> 0.1343). Saving model!
# Validation score improved (0.1343 --> 0.1332). Saving model!
# Validation score improved (0.1332 --> 0.1314). Saving model!
# Validation score improved (0.1314 --> 0.1297). Saving model!
# Validation score improved (0.1297 --> 0.1276). Saving model!
# Validation score improved (0.1276 --> 0.1272). Saving model!
# Validation score improved (0.1272 --> 0.1263). Saving model!
# Validation score improved (0.1263 --> 0.1228). Saving model!
# Validation score improved (0.1228 --> 0.1226). Saving model!
# Validation score improved (0.1226 --> 0.1209). Saving model!
# Validation score improved (0.1209 --> 0.1206). Saving model!
# Validation score improved (0.1206 --> 0.1182). Saving model!
# Validation score improved (0.1182 --> 0.1176). Saving model!
# Validation score improved (0.1176 --> 0.1176). Saving model!
# Validation score improved (0.1176 --> 0.1158). Saving model!
# Validation score improved (0.1158 --> 0.1157). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1157 --> 0.1131). Saving model!
# Validation score improved (0.1131 --> 0.1129). Saving model!
# Validation score improved (0.1129 --> 0.1121). Saving model!
# Validation score improved (0.1121 --> 0.1119). Saving model!
# Validation score improved (0.1119 --> 0.1108). Saving model!
# Validation score improved (0.1108 --> 0.1100). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1100 --> 0.1089). Saving model!
# Validation score improved (0.1089 --> 0.1084). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1084 --> 0.1072). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.1072 --> 0.1061). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1061 --> 0.1047). Saving model!
# Validation score improved (0.1047 --> 0.1034). Saving model!
# Validation score improved (0.1034 --> 0.1022). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1022 --> 0.1015). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.1015 --> 0.1011). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.1011 --> 0.0997). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0997 --> 0.0991). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0991 --> 0.0985). Saving model!
# Validation score improved (0.0985 --> 0.0985). Saving model!
# Validation score improved (0.0985 --> 0.0984). Saving model!
# Validation score improved (0.0984 --> 0.0978). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0978 --> 0.0974). Saving model!
# Validation score improved (0.0974 --> 0.0958). Saving model!
# Validation score improved (0.0958 --> 0.0952). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0952 --> 0.0940). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0940 --> 0.0934). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0934 --> 0.0920). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0920 --> 0.0912). Saving model!
# Validation score improved (0.0912 --> 0.0909). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0909 --> 0.0901). Saving model!
# Validation score improved (0.0901 --> 0.0889). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0889 --> 0.0882). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# Validation score improved (0.0882 --> 0.0880). Saving model!
# Validation score improved (0.0880 --> 0.0879). Saving model!
# Validation score improved (0.0879 --> 0.0868). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# Validation score improved (0.0868 --> 0.0864). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0864 --> 0.0858). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# Validation score improved (0.0858 --> 0.0848). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0848 --> 0.0848). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0848 --> 0.0846). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0846 --> 0.0841). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# Validation score improved (0.0841 --> 0.0840). Saving model!
# Validation score improved (0.0840 --> 0.0831). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# Validation score improved (0.0831 --> 0.0829). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0829 --> 0.0820). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# Validation score improved (0.0820 --> 0.0812). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0812 --> 0.0809). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0809 --> 0.0804). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0804 --> 0.0803). Saving model!
# Validation score improved (0.0803 --> 0.0799). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0799 --> 0.0796). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0796 --> 0.0795). Saving model!
# Validation score improved (0.0795 --> 0.0795). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0795 --> 0.0792). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0792 --> 0.0792). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0792 --> 0.0789). Saving model!
# Validation score improved (0.0789 --> 0.0784). Saving model!
# Validation score improved (0.0784 --> 0.0781). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0781 --> 0.0780). Saving model!
# Validation score improved (0.0780 --> 0.0780). Saving model!
# Validation score improved (0.0780 --> 0.0773). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0773 --> 0.0773). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# Validation score improved (0.0773 --> 0.0766). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0766 --> 0.0761). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0761 --> 0.0758). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# Validation score improved (0.0758 --> 0.0757). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0757 --> 0.0756). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0756 --> 0.0749). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0749 --> 0.0748). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# Validation score improved (0.0748 --> 0.0746). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0746 --> 0.0739). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# Validation score improved (0.0739 --> 0.0738). Saving model!
# Validation score improved (0.0738 --> 0.0734). Saving model!
# Validation score improved (0.0734 --> 0.0732). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0732 --> 0.0728). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# Validation score improved (0.0728 --> 0.0727). Saving model!
# Validation score improved (0.0727 --> 0.0724). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# Validation score improved (0.0724 --> 0.0721). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0721 --> 0.0720). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# Validation score improved (0.0720 --> 0.0715). Saving model!
# Validation score improved (0.0715 --> 0.0714). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0714 --> 0.0714). Saving model!
# EarlyStopping counter: 1 out of 10
# Validation score improved (0.0714 --> 0.0713). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# Validation score improved (0.0713 --> 0.0705). Saving model!
# EarlyStopping counter: 1 out of 10
# EarlyStopping counter: 2 out of 10
# EarlyStopping counter: 3 out of 10
# EarlyStopping counter: 4 out of 10
# EarlyStopping counter: 5 out of 10
# EarlyStopping counter: 6 out of 10
# EarlyStopping counter: 7 out of 10
# EarlyStopping counter: 8 out of 10
# EarlyStopping counter: 9 out of 10
# EarlyStopping counter: 10 out of 10
# Early stopping

# %%
# define dataset
X1=df[['RDAmpM','RDAmpSD', 'QRsa', 'QRaSD']]
y1=df["label"]
X,y=smooth(X1,y1)
X_array = X.values
y_array = y.values.ravel()

# %%
learning_rate= [0.0001]
activation_function=['tanh']
init=['uniform']
neuron1=[128]
neuron2=[64]
epochs=[175]
batch_size=[150]

for lr in learning_rate:
    for af in activation_function:
        for init_mode in init:
            for n1 in neuron1:
                for n2 in neuron2:
                    for ep in epochs:
                        for bs in batch_size:
                            print(f"Running model with learning_rate={lr}, activation_function={af}, init={init_mode}, neuron1={n1}, neuron2={n2}, epochs={ep}, batch_size={bs}")
                            neural_network(X, y, learning_rate=lr, activation_function=af, init=init_mode, neuron1=n1, neuron2=n2, epochs=ep, batch_size=bs, output_path="model.pt",name="shape")

# %%
learning_rate= [0.0001]
activation_function=['tanh']
init=['uniform']
neuron1=[128]
neuron2=[64]
epochs=[175]
batch_size=[150]

for lr in learning_rate:
    for af in activation_function:
        for init_mode in init:
            for n1 in neuron1:
                for n2 in neuron2:
                    for ep in epochs:
                        for bs in batch_size:
                            print(f"Running model with learning_rate={lr}, activation_function={af}, init={init_mode}, neuron1={n1}, neuron2={n2}, epochs={ep}, batch_size={bs}")
                            neural_network_and_ROC(X_array, y_array, learning_rate=lr, activation_function=af, init=init_mode, neuron1=n1, neuron2=n2, epochs=ep, batch_size=bs,name='shape')

# %% [markdown]
# # Best parametre hrv

# %%
X1=df[['RDAmpM','mean_rr','sdsd', 'pnn50','rmssd', 'sdnn','hf_power']]
y1=df["label"]
X,y=smooth(X1,y1)
X_array = X.values
y_array = y.values.ravel()

# %%
learning_rate= [0.001]
activation_function=['tanh']
init=['uniform']
neuron1=[256]
neuron2=[128]
epochs=[150]
batch_size=[100]

for lr in learning_rate:
    for af in activation_function:
        for init_mode in init:
            for n1 in neuron1:
                for n2 in neuron2:
                    for ep in epochs:
                        for bs in batch_size:
                            print(f"Running model with learning_rate={lr}, activation_function={af}, init={init_mode}, neuron1={n1}, neuron2={n2}, epochs={ep}, batch_size={bs}")
                            neural_network(X, y, learning_rate=lr, activation_function=af, init=init_mode, neuron1=n1, neuron2=n2, epochs=ep, batch_size=bs, output_path="model.pt",name="hrv")

# %%
learning_rate= [0.001]
activation_function=['tanh']
init=['uniform']
neuron1=[256]
neuron2=[128]
epochs=[150]
batch_size=[100]
batch_size=[100]

for lr in learning_rate:
    for af in activation_function:
        for init_mode in init:
            for n1 in neuron1:
                for n2 in neuron2:
                    for ep in epochs:
                        for bs in batch_size:
                            print(f"Running model with learning_rate={lr}, activation_function={af}, init={init_mode}, neuron1={n1}, neuron2={n2}, epochs={ep}, batch_size={bs}")
                            neural_network_and_ROC(X_array, y_array, learning_rate=lr, activation_function=af, init=init_mode, neuron1=n1, neuron2=n2, epochs=ep, batch_size=bs,name='hrv')
